# %%
# import 
import numpy as np
import pandas as pd

# %%
# read the file
df = pd.read_csv('./wine3.csv')

# %%
df.head()
# Out:
#   type  alcohol malic   ash  alcalinity  magnesium  phenols  flavanoids  \
# 0    A    13.20  1.78  2.43        15.6      127.0      2.8        3.06
# 1    A    13.20  1.78   NaN         NaN        NaN      NaN         NaN
# 2    A    13.16  2.36   NaN         NaN        NaN      NaN         NaN
# 3    A    14.37  1.95   NaN         NaN        NaN      NaN         NaN
# 4    A    13.24  2.59   NaN         NaN        NaN      NaN         NaN
#
#    nonflavanoids  proanthocyanins  color   hue dilution  proline  \
# 0           0.28             2.29   5.64  1.04     3.92     1065
# 1            NaN              NaN   4.38  1.05      3.4     1050
# 2            NaN              NaN   5.68  1.03     3.17     1185
# 3            NaN              NaN   7.80  0.86     3.45     1480
# 4            NaN              NaN   4.32  1.04     2.93      735
#
#    particular year
# 0             22.0
# 1             38.0
# 2             26.0
# 3             35.0
# 4             35.0

# %%
df.columns
# Out:
# Index(['type', 'alcohol', 'malic', 'ash', 'alcalinity', 'magnesium', 'phenols',
#        'flavanoids', 'nonflavanoids', 'proanthocyanins', 'color', 'hue',
#        'dilution', 'proline', 'particular year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   type             178 non-null    object
#  1   alcohol          178 non-null    float64
#  2   malic            175 non-null    object
#  3   ash              174 non-null    float64
#  4   alcalinity       174 non-null    float64
#  5   magnesium        174 non-null    float64
#  6   phenols          9 non-null      float64
#  7   flavanoids       174 non-null    float64
#  8   nonflavanoids    174 non-null    float64
#  9   proanthocyanins  174 non-null    float64
#  10  color            178 non-null    float64
#  11  hue              178 non-null    float64
#  12  dilution         178 non-null    object
#  13  proline          178 non-null    int64
#  14  particular year  175 non-null    float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 21.0+ KB

# %%
df.describe()
# Out:
#           alcohol         ash  alcalinity   magnesium   phenols  flavanoids  \
# count  178.000000  174.000000  174.000000  174.000000  9.000000  174.000000
# mean    12.994831    2.362414   19.554598   99.551724  1.765556    2.005920
# std      0.806669    0.273113    3.309010   14.342837  0.449697    0.996906
# min     11.030000    1.360000   10.600000   70.000000  1.250000    0.340000
# 25%     12.362500    2.210000   17.200000   88.000000  1.590000    1.125000
# 50%     13.050000    2.360000   19.500000   97.500000  1.680000    2.100000
# 75%     13.662500    2.547500   21.500000  107.000000  1.800000    2.842500
# max     14.830000    3.230000   30.000000  162.000000  2.800000    5.080000
#
#        nonflavanoids  proanthocyanins       color         hue      proline  \
# count     174.000000       174.000000  178.000000  178.000000   178.000000
# mean        0.363333         1.580977    5.058090    0.957449   746.893258
# ...

# %%
df
# Out:
#     type  alcohol malic   ash  alcalinity  magnesium  phenols  flavanoids  \
# 0      A    13.20  1.78  2.43        15.6      127.0     2.80        3.06
# 1      A    13.20  1.78   NaN         NaN        NaN      NaN         NaN
# 2      A    13.16  2.36   NaN         NaN        NaN      NaN         NaN
# 3      A    14.37  1.95   NaN         NaN        NaN      NaN         NaN
# 4      A    13.24  2.59   NaN         NaN        NaN      NaN         NaN
# ..   ...      ...   ...   ...         ...        ...      ...         ...
# 173    C    13.71  5.65  2.45        20.5       95.0     1.68        0.61
# 174    C    13.40  3.91  2.48        23.0      102.0     1.80        0.75
# 175    C    13.27  4.28  2.26        20.0      120.0     1.59        0.69
# 176    C    13.17  2.59  2.37        20.0      120.0     1.65        0.68
# 177    C    14.13   4.1  2.74        24.5       96.0     2.05        0.76
#
#      nonflavanoids  proanthocyanins  color   hue dilution  proline  \
# ...

# %%
df_drop = df.dropna(axis=1,how='any',thresh=df.shape[0]*0.8)

# %%
df_drop
# Out:
#     type  alcohol malic   ash  alcalinity  magnesium  flavanoids  \
# 0      A    13.20  1.78  2.43        15.6      127.0        3.06
# 1      A    13.20  1.78   NaN         NaN        NaN         NaN
# 2      A    13.16  2.36   NaN         NaN        NaN         NaN
# 3      A    14.37  1.95   NaN         NaN        NaN         NaN
# 4      A    13.24  2.59   NaN         NaN        NaN         NaN
# ..   ...      ...   ...   ...         ...        ...         ...
# 173    C    13.71  5.65  2.45        20.5       95.0        0.61
# 174    C    13.40  3.91  2.48        23.0      102.0        0.75
# 175    C    13.27  4.28  2.26        20.0      120.0        0.69
# 176    C    13.17  2.59  2.37        20.0      120.0        0.68
# 177    C    14.13   4.1  2.74        24.5       96.0        0.76
#
#      nonflavanoids  proanthocyanins  color   hue dilution  proline  \
# 0             0.28             2.29   5.64  1.04     3.92     1065
# ...

# %%
df_p.items
# Out:
# <bound method Series.items of type                 0
# alcohol              0
# malic                3
# ash                  4
# alcalinity           4
# magnesium            4
# phenols            169
# flavanoids           4
# nonflavanoids        4
# proanthocyanins      4
# color                0
# hue                  0
# dilution             0
# proline              0
# particular year      3
# dtype: int64>

# %%
from sklearn.impute import SimpleImputer
model_ss = SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
df_2 = model_ss.fit_transform(df_drop[[c for c in df_drop.columns]])

# %%
df_2
# Out:
# array([['A', 13.2, '1.78', ..., '3.92', 1065, 22.0],
#        ['A', 13.2, '1.78', ..., '3.4', 1050, 38.0],
#        ['A', 13.16, '2.36', ..., '3.17', 1185, 26.0],
#        ...,
#        ['C', 13.27, '4.28', ..., '1.56', 835, 18.0],
#        ['C', 13.17, '2.59', ..., '1.62', 840, 29.0],
#        ['C', 14.13, '4.1', ..., '1.6', 560, 29.0]], dtype=object)

# %%
df_2 = pd.DataFrame(data=df_2,columns=[[c for c in df_drop.columns]])

# %%
df_2
# Out:
#     type alcohol malic   ash alcalinity magnesium flavanoids nonflavanoids  \
# 0      A    13.2  1.78  2.43       15.6     127.0       3.06          0.28
# 1      A    13.2  1.78  2.28       20.0      88.0       2.65          0.43
# 2      A   13.16  2.36  2.28       20.0      88.0       2.65          0.43
# 3      A   14.37  1.95  2.28       20.0      88.0       2.65          0.43
# 4      A   13.24  2.59  2.28       20.0      88.0       2.65          0.43
# ..   ...     ...   ...   ...        ...       ...        ...           ...
# 173    C   13.71  5.65  2.45       20.5      95.0       0.61          0.52
# 174    C    13.4  3.91  2.48       23.0     102.0       0.75          0.43
# 175    C   13.27  4.28  2.26       20.0     120.0       0.69          0.43
# 176    C   13.17  2.59  2.37       20.0     120.0       0.68          0.53
# 177    C   14.13   4.1  2.74       24.5      96.0       0.76          0.56
#
#     proanthocyanins color   hue dilution proline particular year
# ...

# %%
df_drop = df.dropna(axis=1, how='any', thresh=)
